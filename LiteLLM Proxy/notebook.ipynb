# %%
# %pip install -U litellm anthropic python-dotenv

# %%
# %pip install -U "litellm[proxy]"

# %%
from dotenv import load_dotenv
import os

load_dotenv()
anthropic_api_key = os.getenv("GEMINI_API_KEY")

# %%
from anthropic import Anthropic

client = Anthropic(api_key="anything", base_url="http://localhost:4000")

# %%
response = client.messages.create(model="gemini", max_tokens=100, 
                                 messages=[{"role": "user", "content": "What is quantum computing?"}, 
                                   ])
print(response.content[0].text)
# Out:
# At a high level, **quantum computing** is a rapidly-emerging technology that harnesses the laws of quantum mechanics to solve problems too complex for classical computers.
#
# While ordinary computers (the ones you use every day) process information as bits of 0s and 1s, quantum computers use **qubits**, which can exist in a state of **superposition**. This fundamental difference allows quantum computers to process vast amounts of information simultaneously.
#
# To understand quantum computing,
